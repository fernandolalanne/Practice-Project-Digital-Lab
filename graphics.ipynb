# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import plotly.graph_objs as go
import plotly.express as px
import dash
from dash import html
from dash import dcc

# %%
df_covid = pd.read_csv('Data/covid-data.csv', delimiter=',')
df_eco_covid = pd.read_csv('Data/data_econo_covid.csv', delimiter=';')
df_education = pd.read_csv('Data/Education-GDP.csv', delimiter=',')
df_GDP = pd.read_csv('Data/GDP.csv', delimiter=',')
df_gini = pd.read_csv('Data/gini.csv', delimiter=',')
df_poverty = pd.read_csv('Data/poverty-explorer.csv', delimiter=',')
df_trade = pd.read_csv('Data/trade.csv', delimiter=',')
df_HICP_FR = pd.read_csv('Data/HICP_FR.csv', delimiter=',') #The Harmonized Consumer Price Index (HICP) provides a standardized measure of inflation across EU countries. 
df_HICP_BE = pd.read_csv('Data/HICP_BE.csv', delimiter=',')
df_HICP_BU_21 = pd.read_csv('Data/HICP_BU_21.csv', delimiter=',')
df_HICP_FI = pd.read_csv('Data/HICP_FI.csv', delimiter=',')
df_HICP_food_europe = pd.read_csv('Data/HICP_food_europe.csv', delimiter=',')
df_HICP_GR = pd.read_csv('Data/HICP_GR.csv', delimiter=',')
df_HICP_nrj_BU = pd.read_csv('Data/HICP_nrj_BU.csv', delimiter=',')
df_HICP_nrj_GE = pd.read_csv('Data/HICP_nrj_GE.csv', delimiter=',')
df_HICP_nrj_GR = pd.read_csv('Data/HICP_nrj_GR.csv', delimiter=',')
df_HICP_nrj_IT = pd.read_csv('Data/HICP_nrj_IT.csv', delimiter=',')
df_HICP_PO = pd.read_csv('Data/HICP_PO.csv', delimiter=',') 
df_HICP_RO = pd.read_csv('Data/HICP_RO.csv', delimiter=',')
df_HICP_HU = pd.read_csv('Data/HICP_HU.csv', delimiter=',')

# %% [markdown]
# # All Covid data

# %%
df_covid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          1.0        1.0
# 1           AFG      Asia  Afghanistan  2020-01-04          1.0        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          1.0        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          1.0        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          1.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 384463      ZWE    Africa     Zimbabwe  2024-03-01     266350.0        0.0
# 384464      ZWE    Africa     Zimbabwe  2024-03-02     266350.0        0.0
# 384465      ZWE    Africa     Zimbabwe  2024-03-03     266350.0        0.0
# 384466      ZWE    Africa     Zimbabwe  2024-03-04     266350.0        0.0
# 384467      ZWE    Africa     Zimbabwe  2024-03-05     266350.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 384463                 0.0        5737.0         0.0                  0.0
# 384464                 0.0        5737.0         0.0                  0.0
# 384465                 0.0        5737.0         0.0                  0.0
# 384466                 0.0        5737.0         0.0                  0.0
# 384467                 0.0        5737.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 384463  ...          30.7                  36.791                         1.7
# 384464  ...          30.7                  36.791                         1.7
# 384465  ...          30.7                  36.791                         1.7
# 384466  ...          30.7                  36.791                         1.7
# 384467  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 384463            61.49                    0.571  16320539.0
# 384464            61.49                    0.571  16320539.0
# 384465            61.49                    0.571  16320539.0
# 384466            61.49                    0.571  16320539.0
# 384467            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 384463                                   NaN                          NaN
# 384464                                   NaN                          NaN
# 384465                                   NaN                          NaN
# 384466                                   NaN                          NaN
# 384467                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 384463               NaN                                      NaN
# 384464               NaN                                      NaN
# 384465               NaN                                      NaN
# 384466               NaN                                      NaN
# 384467               NaN                                      NaN
#
# [384468 rows x 67 columns]

# %%
df_covid_country = df_covid[df_covid['location'] == 'Italy']

import plotly.express as px

fig = px.line(
    df_covid_country,
    x='date',
    y='weekly_hosp_admissions_per_million',
    title='VARIABLE TO CHECK Over Time in European Countries',
    labels={'weekly_hosp_admissions_per_million': 'Variable', 'location': 'European Countries'},
)

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Variable',
)

fig.show()

# %%
df_covid_variable = df_covid_country['weekly_hosp_admissions_per_million']

df_covid_variable_slice = df_covid_variable.iloc[200:250]
print(df_covid_variable_slice)
# Out:
# 164596     9.130
# 164597     9.265
# 164598     9.452
# 164599     9.096
# 164600     9.316
# 164601     9.486
# 164602     9.096
# 164603     8.825
# 164604     8.825
# 164605     8.740
# 164606     8.876
# 164607     8.876
# 164608     8.994
# 164609     9.672
# 164610     9.469
# 164611     9.672
# 164612     9.790
# 164613     9.740
# 164614     9.587
# 164615     9.790
# 164616     9.706
# 164617     9.672
# 164618     9.943
# 164619    10.180
# 164620    10.248
# 164621    10.332
# 164622    10.315
# 164623    10.180
# 164624    11.315
# 164625    11.925
# 164626    11.975
# 164627    12.196
# 164628    13.195
# 164629    13.669
# 164630    14.059
# 164631    14.550
# 164632    14.669
# 164633    15.668
# 164634    16.583
# 164635    16.430
# 164636    16.769
# 164637    17.023
# 164638    17.125
# 164639    17.667
# 164640    18.293
# 164641    18.768
# 164642    19.344
# 164643    19.530
# 164644    20.733
# 164645    21.054
# Name: weekly_hosp_admissions_per_million, dtype: float64

# %% [markdown]
# # Europe only

# %%
import pandas as pd

# Load the dataframes
df_covid_HICP_europe = pd.read_csv('df_covid_HICP_europe.csv', delimiter=',')
df_economics_europe = pd.read_csv('df_economics_europe.csv', delimiter=',')

# Convert 'date' column to datetime
df_covid_HICP_europe['date'] = pd.to_datetime(df_covid_HICP_europe['date'])
df_economics_europe['date'] = pd.to_datetime(df_economics_europe['Year'], format='%Y')

# Interpolate economic indicators data to monthly frequency
df_economics_monthly = df_economics_europe.groupby('location').apply(lambda x: x.set_index('date').resample('M').interpolate(method='linear'))

# Reset the index without adding the existing index as a new column
df_economics_monthly.reset_index(drop=True, inplace=True)

# Merge economic indicators data with COVID-related data
merged_df = pd.merge(df_covid_HICP_europe, df_economics_monthly, on=['location', 'date'], how='inner')

print(merged_df)
# Out:
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#
# /tmp/ipykernel_6252/491649033.py:12: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/491649033.py:12: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6252/491649033.py in ?()
#      14 # Reset the index without adding the existing index as a new column
#      15 df_economics_monthly.reset_index(drop=True, inplace=True)
#      16
#      17 # Merge economic indicators data with COVID-related data
# ---> 18 merged_df = pd.merge(df_covid_HICP_europe, df_economics_monthly, on=['location', 'date'], how='inner')
#      19
#      20 print(merged_df)
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#    1294                         #  the latter of which will raise
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#    1300                             right_keys.append(right.index._values)
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1906             values = self.xs(key, axis=other_axes[0])._values
#    1907         elif self._is_level_reference(key, axis=axis):
#    1908             values = self.axes[axis].get_level_values(key)._values
#    1909         else:
# -> 1910             raise KeyError(key)
#    1911
#    1912         # Check for duplicates
#    1913         if values.ndim > 1:
#
# KeyError: 'date'

# %%
df_covid_HICP_europe = pd.read_csv('df_covid_HICP_europe.csv', delimiter=',')
df_economics_europe = pd.read_csv('df_economics_europe.csv', delimiter=',')

# %%
# Convert 'date' column to datetime
df_covid_HICP_europe['date'] = pd.to_datetime(df_covid_HICP_europe['date'])
df_economics_europe['date'] = pd.to_datetime(df_economics_europe['Year'], format='%Y')

# %%
# Interpolate economic indicators data to monthly frequency
#df_economics_monthly = df_economics_europe.groupby('location').apply(lambda x: x.set_index('date').infer_objects().resample('ME').interpolate(method='linear'))
df_economics_monthly = df_economics_europe.groupby('location').apply(lambda x: x.set_index('date').resample('ME').interpolate(method='linear')).reset_index()
# Out:
# /tmp/ipykernel_6252/656992172.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/656992172.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/656992172.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/656992172.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/656992172.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/656992172.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/656992172.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/656992172.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/656992172.py:3: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6252/656992172.py in ?()
#       1 # Interpolate economic indicators data to monthly frequency
#       2 #df_economics_monthly = df_economics_europe.groupby('location').apply(lambda x: x.set_index('date').infer_objects().resample('ME').interpolate(method='linear'))
# ----> 3 df_economics_monthly = df_economics_europe.groupby('location').apply(lambda x: x.set_index('date').resample('ME').interpolate(method='linear')).reset_index()
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6452                     level_values = algorithms.take(
#    6453                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6454                     )
#    6455
# -> 6456                 new_obj.insert(
#    6457                     0,
#    6458                     name,
#    6459                     level_values,
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, loc, column, value, allow_duplicates)
#    5141                 "'self.flags.allows_duplicate_labels' is False."
#    5142             )
#    5143         if not allow_duplicates and column in self.columns:
#    5144             # Should this be a different kind of error??
# -> 5145             raise ValueError(f"cannot insert {column}, already exists")
#    5146         if not is_integer(loc):
#    5147             raise TypeError("loc must be int")
#    5148         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert location, already exists

# %%
# Interpolate economic indicators data to monthly frequency
#df_economics_monthly = df_economics_europe.groupby('location').apply(lambda x: x.set_index('date').resample('ME').interpolate(method='linear')).reset_index(drop=True)

# %%
# Merge economic indicators data with COVID-related data
merged_df = pd.merge(df_covid_HICP_europe, df_economics_monthly, on=['location', 'date'], how='inner')
merged_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6252/2429337760.py in ?()
#       1 # Merge economic indicators data with COVID-related data
# ----> 2 merged_df = pd.merge(df_covid_HICP_europe, df_economics_monthly, on=['location', 'date'], how='inner')
#       3 merged_df
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#    1294                         #  the latter of which will raise
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#    1300                             right_keys.append(right.index._values)
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1901         axis = self._get_axis_number(axis)
#    1902         other_axes = [ax for ax in range(self._AXIS_LEN) if ax != axis]
#    1903
#    1904         if self._is_label_reference(key, axis=axis):
# -> 1905             self._check_label_or_level_ambiguity(key, axis=axis)
#    1906             values = self.xs(key, axis=other_axes[0])._values
#    1907         elif self._is_level_reference(key, axis=axis):
#    1908             values = self.axes[axis].get_level_values(key)._values
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1863             msg = (
#    1864                 f"'{key}' is both {level_article} {level_type} level and "
#    1865                 f"{label_article} {label_type} label, which is ambiguous."
#    1866             )
# -> 1867             raise ValueError(msg)
#
# ValueError: 'location' is both an index level and a column label, which is ambiguous.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import plotly.graph_objs as go
import plotly.express as px
import dash
from dash import html
from dash import dcc

# %%
df_covid = pd.read_csv('Data/covid-data.csv', delimiter=',')
df_eco_covid = pd.read_csv('Data/data_econo_covid.csv', delimiter=';')
df_education = pd.read_csv('Data/Education-GDP.csv', delimiter=',')
df_GDP = pd.read_csv('Data/GDP.csv', delimiter=',')
df_gini = pd.read_csv('Data/gini.csv', delimiter=',')
df_poverty = pd.read_csv('Data/poverty-explorer.csv', delimiter=',')
df_trade = pd.read_csv('Data/trade.csv', delimiter=',')
df_HICP_FR = pd.read_csv('Data/HICP_FR.csv', delimiter=',') #The Harmonized Consumer Price Index (HICP) provides a standardized measure of inflation across EU countries. 
df_HICP_BE = pd.read_csv('Data/HICP_BE.csv', delimiter=',')
df_HICP_BU_21 = pd.read_csv('Data/HICP_BU_21.csv', delimiter=',')
df_HICP_FI = pd.read_csv('Data/HICP_FI.csv', delimiter=',')
df_HICP_food_europe = pd.read_csv('Data/HICP_food_europe.csv', delimiter=',')
df_HICP_GR = pd.read_csv('Data/HICP_GR.csv', delimiter=',')
df_HICP_nrj_BU = pd.read_csv('Data/HICP_nrj_BU.csv', delimiter=',')
df_HICP_nrj_GE = pd.read_csv('Data/HICP_nrj_GE.csv', delimiter=',')
df_HICP_nrj_GR = pd.read_csv('Data/HICP_nrj_GR.csv', delimiter=',')
df_HICP_nrj_IT = pd.read_csv('Data/HICP_nrj_IT.csv', delimiter=',')
df_HICP_PO = pd.read_csv('Data/HICP_PO.csv', delimiter=',') 
df_HICP_RO = pd.read_csv('Data/HICP_RO.csv', delimiter=',')
df_HICP_HU = pd.read_csv('Data/HICP_HU.csv', delimiter=',')

# %% [markdown]
# # All Covid data

# %%
df_covid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          1.0        1.0
# 1           AFG      Asia  Afghanistan  2020-01-04          1.0        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          1.0        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          1.0        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          1.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 384463      ZWE    Africa     Zimbabwe  2024-03-01     266350.0        0.0
# 384464      ZWE    Africa     Zimbabwe  2024-03-02     266350.0        0.0
# 384465      ZWE    Africa     Zimbabwe  2024-03-03     266350.0        0.0
# 384466      ZWE    Africa     Zimbabwe  2024-03-04     266350.0        0.0
# 384467      ZWE    Africa     Zimbabwe  2024-03-05     266350.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 384463                 0.0        5737.0         0.0                  0.0
# 384464                 0.0        5737.0         0.0                  0.0
# 384465                 0.0        5737.0         0.0                  0.0
# 384466                 0.0        5737.0         0.0                  0.0
# 384467                 0.0        5737.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 384463  ...          30.7                  36.791                         1.7
# 384464  ...          30.7                  36.791                         1.7
# 384465  ...          30.7                  36.791                         1.7
# 384466  ...          30.7                  36.791                         1.7
# 384467  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 384463            61.49                    0.571  16320539.0
# 384464            61.49                    0.571  16320539.0
# 384465            61.49                    0.571  16320539.0
# 384466            61.49                    0.571  16320539.0
# 384467            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 384463                                   NaN                          NaN
# 384464                                   NaN                          NaN
# 384465                                   NaN                          NaN
# 384466                                   NaN                          NaN
# 384467                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 384463               NaN                                      NaN
# 384464               NaN                                      NaN
# 384465               NaN                                      NaN
# 384466               NaN                                      NaN
# 384467               NaN                                      NaN
#
# [384468 rows x 67 columns]

# %%
df_covid_country = df_covid[df_covid['location'] == 'Italy']

import plotly.express as px

fig = px.line(
    df_covid_country,
    x='date',
    y='weekly_hosp_admissions_per_million',
    title='VARIABLE TO CHECK Over Time in European Countries',
    labels={'weekly_hosp_admissions_per_million': 'Variable', 'location': 'European Countries'},
)

fig.update_layout(
    xaxis_title='Date',
    yaxis_title='Variable',
)

fig.show()

# %%
df_covid_variable = df_covid_country['weekly_hosp_admissions_per_million']

df_covid_variable_slice = df_covid_variable.iloc[200:250]
print(df_covid_variable_slice)
# Out:
# 164596     9.130
# 164597     9.265
# 164598     9.452
# 164599     9.096
# 164600     9.316
# 164601     9.486
# 164602     9.096
# 164603     8.825
# 164604     8.825
# 164605     8.740
# 164606     8.876
# 164607     8.876
# 164608     8.994
# 164609     9.672
# 164610     9.469
# 164611     9.672
# 164612     9.790
# 164613     9.740
# 164614     9.587
# 164615     9.790
# 164616     9.706
# 164617     9.672
# 164618     9.943
# 164619    10.180
# 164620    10.248
# 164621    10.332
# 164622    10.315
# 164623    10.180
# 164624    11.315
# 164625    11.925
# 164626    11.975
# 164627    12.196
# 164628    13.195
# 164629    13.669
# 164630    14.059
# 164631    14.550
# 164632    14.669
# 164633    15.668
# 164634    16.583
# 164635    16.430
# 164636    16.769
# 164637    17.023
# 164638    17.125
# 164639    17.667
# 164640    18.293
# 164641    18.768
# 164642    19.344
# 164643    19.530
# 164644    20.733
# 164645    21.054
# Name: weekly_hosp_admissions_per_million, dtype: float64

# %% [markdown]
# # Europe only

# %%
df_covid_HICP_europe = pd.read_csv('df_covid_HICP_europe.csv', delimiter=',')
df_economics_europe = pd.read_csv('df_economics_europe.csv', delimiter=',')

# %%
# Convert 'date' column to datetime
df_covid_HICP_europe['date'] = pd.to_datetime(df_covid_HICP_europe['date'])
df_economics_europe['date'] = pd.to_datetime(df_economics_europe['Year'], format='%Y')

# %%
# Interpolate economic indicators data to monthly frequency
#df_economics_monthly = df_economics_europe.groupby('location').apply(lambda x: x.set_index('date').infer_objects().resample('ME').interpolate(method='linear'))
df_economics_monthly = df_economics_europe.groupby('location').apply(lambda x: x.set_index('date').resample('ME').interpolate(method='linear'))
# Out:
# /tmp/ipykernel_6252/1365391674.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/1365391674.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/1365391674.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/1365391674.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/1365391674.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/1365391674.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/1365391674.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/1365391674.py:3: FutureWarning:
#
# DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#
# /tmp/ipykernel_6252/1365391674.py:3: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
# Interpolate economic indicators data to monthly frequency
#df_economics_monthly = df_economics_europe.groupby('location').apply(lambda x: x.set_index('date').resample('ME').interpolate(method='linear')).reset_index(drop=True)

# %%
# Merge economic indicators data with COVID-related data
merged_df = pd.merge(df_covid_HICP_europe, df_economics_monthly, on=['location', 'date'], how='inner')
merged_df
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# /tmp/ipykernel_6252/2429337760.py in ?()
#
#       1 # Merge economic indicators data with COVID-related data
#
# ----> 2 merged_df = pd.merge(df_covid_HICP_europe, df_economics_monthly, on=['location', 'date'], how='inner')
#
#       3 merged_df
#
#
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#
#     166             validate=validate,
#
#     167             copy=copy,
#
#     168         )
#
#     169     else:
#
# --> 170         op = _MergeOperation(
#
#     171             left_df,
#
#     172             right_df,
#
#     173             how=how,
#
#
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#
#     790             self.right_join_keys,
#
#     791             self.join_names,
#
#     792             left_drop,
#
#     793             right_drop,
#
# --> 794         ) = self._get_merge_keys()
#
#     795
#
#     796         if left_drop:
#
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
#
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self)
#
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#
#    1294                         #  the latter of which will raise
#
#    1295                         rk = cast(Hashable, rk)
#
#    1296                         if rk is not None:
#
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#
#    1298                         else:
#
#    1299                             # work-around for merge_asof(right_index=True)
#
#    1300                             right_keys.append(right.index._values)
#
#
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#
#    1901         axis = self._get_axis_number(axis)
#
#    1902         other_axes = [ax for ax in range(self._AXIS_LEN) if ax != axis]
#
#    1903
#
#    1904         if self._is_label_reference(key, axis=axis):
#
# -> 1905             self._check_label_or_level_ambiguity(key, axis=axis)
#
#    1906             values = self.xs(key, axis=other_axes[0])._values
#
#    1907         elif self._is_level_reference(key, axis=axis):
#
#    1908             values = self.axes[axis].get_level_values(key)._values
#
#
#
# ~/anaconda3/envs/ml/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#
#    1863             msg = (
#
#    1864                 f"'{key}' is both {level_article} {level_type} level and "
#
#    1865                 f"{label_article} {label_type} label, which is ambiguous."
#
#    1866             )
#
# -> 1867             raise ValueError(msg)
#
#
#
# ValueError: 'location' is both an index level and a column label, which is ambiguous.

# %%
'''
# Plot the trends
plt.figure(figsize=(12, 8))

# Plot economic indicators
plt.plot(merged_df['date'], merged_df['GDP'], label='GDP')
plt.plot(merged_df['date'], merged_df['education'], label='Education')
plt.plot(merged_df['date'], merged_df['gini'], label='Gini Index')
plt.plot(merged_df['date'], merged_df['trade'], label='Trade')
plt.plot(merged_df['date'], merged_df['median_income'], label='Median Income')
plt.plot(merged_df['date'], merged_df['poorest_decile_threshold'], label='Poorest Decile Threshold')
plt.plot(merged_df['date'], merged_df['richest_decile_threshold'], label='Richest Decile Threshold')

# Plot COVID-related variables
plt.plot(merged_df['date'], merged_df['total_deaths'], label='Total Deaths', linestyle='--')
plt.plot(merged_df['date'], merged_df['stringency_index'], label='Stringency Index', linestyle='--')
plt.plot(merged_df['date'], merged_df['total_cases_per_million'], label='Total Cases Per Million', linestyle='--')
plt.plot(merged_df['date'], merged_df['new_cases_smoothed_per_million'], label='New Cases Smoothed Per Million', linestyle='--')
plt.plot(merged_df['date'], merged_df['weekly_hosp_admissions_per_million'], label='Weekly Hosp Admissions Per Million', linestyle='--')

plt.title('Trends of Economic Indicators and COVID-related Variables over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
'''

# %%
'''
# Plot the trends
plt.figure(figsize=(12, 8))

# Plot economic indicators
plt.plot(merged_df['date'], merged_df['GDP'], label='GDP')
plt.plot(merged_df['date'], merged_df['education'], label='Education')
plt.plot(merged_df['date'], merged_df['gini'], label='Gini Index')
plt.plot(merged_df['date'], merged_df['trade'], label='Trade')
plt.plot(merged_df['date'], merged_df['median_income'], label='Median Income')
plt.plot(merged_df['date'], merged_df['poorest_decile_threshold'], label='Poorest Decile Threshold')
plt.plot(merged_df['date'], merged_df['richest_decile_threshold'], label='Richest Decile Threshold')

# Plot COVID-related variables
plt.plot(merged_df['date'], merged_df['total_deaths'], label='Total Deaths', linestyle='--')
plt.plot(merged_df['date'], merged_df['stringency_index'], label='Stringency Index', linestyle='--')
plt.plot(merged_df['date'], merged_df['total_cases_per_million'], label='Total Cases Per Million', linestyle='--')
plt.plot(merged_df['date'], merged_df['new_cases_smoothed_per_million'], label='New Cases Smoothed Per Million', linestyle='--')
plt.plot(merged_df['date'], merged_df['weekly_hosp_admissions_per_million'], label='Weekly Hosp Admissions Per Million', linestyle='--')

plt.title('Trends of Economic Indicators and COVID-related Variables over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
'''
